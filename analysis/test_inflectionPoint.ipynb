# %%
# %load_ext autoreload
# %autoreload 2
import geopandas as gpd
directory = '/scratch/6256481/'


import sys
sys.path.insert(0, directory + f'python/py_code/')
import numpy as np
from pipeline.support import get_local_utm_projection, node_position, adjust_new_segments
from analysis.cycle_identification import find_connected_side
from pipeline.get_orthogonals import get_orthogonals
from pipeline.dem import find_dem

from shapely.geometry import Point, LineString

from pipeline.support import create_dir
from glob import glob
# from python.py_code.old.remove_mannual_add import remove_manual_add, remove_man_add

from pipeline.line_functions import get_bend_dist_out


import pandas as pd
# from python.py_code.old.reach_def import create_ud_id, create_new_segments

from datetime import datetime as dt
from pipeline.inflection_points import inflection_points, inflection_points_curve


from pipeline.connect_geometries import merge_centerlines
from pipeline.smoothing import SG_smoothing
from tqdm import tqdm
from scipy.stats import trim_mean
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

import xarray as xr
import shapely

# %%
singleConfFiles = np.sort(glob(directory + f'results/single_values/*conf.nc'))

# %%
c = 'as'
i = '01'

create_new = False
vector_save_file = directory +f'results/new_segments/vector/{c}_{i}_reach_new_segments.gpkg'
node_save_file   = directory +f'results/new_segments/node/{c}_{i}_node_new_segments.gpkg'

# %%
df       = gpd.read_file(vector_save_file)
dfNode   = gpd.read_file(node_save_file)

df = adjust_new_segments(df)

# %%
def plot(combinedLine, combinedLineSmooth, infP, infPTotal,apexP, apexPO):
    f, ax = plt.subplots(nrows=1, ncols=1, figsize = [10,6], sharey=True)

    ax.plot(*combinedLine.xy      , color = 'orange'   , zorder = 0)
    ax.plot(*combinedLineSmooth.xy, color = 'chocolate', zorder = 10, linestyle = '--')

    # plot inflections
    if isinstance(infP, list):
        for i, ip in enumerate(infP):
            plt.scatter(*ip.xy, zorder = 100, c = 'black', marker = '.')
        for i, ip in enumerate(infPTotal):
            plt.scatter(*ip.xy, zorder = 80, c = 'lime', marker = '.')
    if isinstance(apexP, list):
        for i, ap in enumerate(apexP):
            plt.scatter(*ap.xy, zorder = 100, c = 'red', marker = '^')
            plt.scatter(*apexPO[i].xy, zorder = 100, c = 'red', marker = '1')
            

    ax.set_aspect('equal', adjustable='box')
    ax.axis('off')



    plt.tight_layout()
    plt.show()

def plot_inflection_points_curve(inf, infT, apexP, apexPO, line, lineO):
    plt.figure(figsize=[10,8])
        # plt.scatter(*testApex, label = arcSign[ip], marker = '^', s = 25, zorder = 200, c = 'green')
    # for i in range(len(apexP)):
    #     plt.scatter(*apexP[i].xy , s = 30, marker = 'h', zorder = 150, c = 'red')
    #     plt.scatter(*apexPO[i].xy, s = 30, marker = '1', zorder = 100, c = 'red')

    for i in range(len(inf)):
        plt.scatter(*inf[i]    , s = 30, marker = '.', zorder = 100, c = 'limegreen')
        # plt.scatter(*inf[i]    , s = 20, marker = '.', zorder = 100, label = i) 
    plt.scatter(*inf[i]    , s = 100, marker = '.', zorder = 100, c = 'limegreen')

    for i,p in enumerate(infT):
        plt.scatter(*p    , s = 30, marker = '.', zorder = 50, c = 'black')

    plt.plot(*line.xy , zorder = 10, color = 'blue', linestyle = '--')
    plt.plot(*lineO.xy, zorder = 5 , color = 'cyan', linestyle = '-')
    plt.axis('equal')
    plt.axis('off')
    # plt.legend()
    plt.show()

# %%
# get combined reach id from reach id
idR = [14277900011, 14277700091, 14277700081, 14277700071, 14277700061, 14277700161]
for iD in idR:
    print(int(df[df['reach_id'] == iD]['combined_reach_id'].iloc[0]))
# ids = df.loc[df['include_flag'] == '0','combined_reach_id'].unique()
# ids[1685:1688]
# Out:
# 8287
# 8288
# 8288
# 8288
# 8288
# 8288

# %%
minLenFactor = 4*12

ids = df.loc[df['include_flag'] == '0','combined_reach_id'].unique()

ids = [12881, 12906, 12943, 12945, 12950, 13030, 13066, 13184, 13326]
ids = [5525]
# ids = 6751, 6965, 7081

dfSF = pd.read_csv(directory + 'results/smoothingFactor.csv')
ids = [5525, 6751, 6965, 7081, 7312, 7608, 8143]
for id in tqdm(ids):

       dfReach      = df[df['combined_reach_id'] == id].copy()
       dfReachNodes = dfNode[dfNode['reach_id'].isin(dfReach['reach_id'].values)].copy()

       GroupedCRS = dfReach.groupby('localCRS', as_index = False).size()
       reachCRS   = GroupedCRS.loc[GroupedCRS['size'] == GroupedCRS['size'].max()
                                   ,'localCRS'].iloc[0]

       dfReach      = dfReach.to_crs(reachCRS)
       dfReachNodes = dfReachNodes.to_crs(reachCRS)
       df.loc[dfReach.index, 'combined_reach_crs'] = reachCRS           

       combinedLine, _, _ = merge_centerlines(dfReach, df, reachCRS)

       ###########################
       # Set width factor value
       ###########################
       widthVar    = 'width'
       factorWidth = dfReach['combined_reach_width'].iloc[0]

       if dfReachNodes[widthVar].std() > (factorWidth/2):
              factorWidth = trim_mean(dfReachNodes[widthVar], 0.05)
       if np.isnan(factorWidth):
              factorWidth = dfReachNodes[widthVar].mean()
       ###########################
       # Width Ratio
       ###########################
       widthRatio = dfReachNodes['width'] / dfReachNodes['max_width']
       df.loc[dfReach.index, 'widthRatio'] = np.nanmean(widthRatio)

       ###########################
       # Smoothing
       ###########################
       factorRow       = abs(dfSF['combined_reach_width'] - factorWidth).argsort()
       smoothingFactor = dfSF.loc[factorRow, 'smoothFactor'].iloc[0]
       
       smoothing_window = smoothingFactor*int(factorWidth) # Smoothing window based on mean node max width
       
       # Smooth centerline
       combinedLineSmooth = SG_smoothing(combinedLine, smoothing_window, factorWidth)
       if len(combinedLine.coords) < 3:
              combinedLineSmooth = combinedLineSmooth.segmentize(1) 

       # find node positions along combined centerline
       dfReachNodes       = node_position(combinedLineSmooth, dfReachNodes)

       dt1 = dt.now()
       (sin, bendSin,inf, infT, amplitudes, apexPList, apexPOList, curveList, bendLines, 
              infLines,bendWidths, bendMaxWidths, bendDO, bendLen) = inflection_points_curve(combinedLineSmooth, dfReach, dfReachNodes)
       dt2 = dt.now()
       # print('newMethod: ', dt2 - dt1)
       # print(len(bendDO), len(np.unique(bendDO)))
       plot_inflection_points_curve(inf,infT, apexPList, apexPOList, combinedLineSmooth, combinedLine)

       print()
       print()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# 297 297
# Smoothing broken at window size 2 (2.0056367420884937) (9999)
#  14%|█▍        | 1/7 [02:28<14:53, 148.97s/it]
# 174 174
# Smoothing broken at window size 2 (2.0746938961476493) (9999)
#  29%|██▊       | 2/7 [03:28<08:01, 96.39s/it]
# 218 218
# Smoothing broken at window size 2 (2.0765565890283786) (9999)
#  43%|████▎     | 3/7 [05:16<06:46, 101.64s/it]
# 269 269
# Smoothing broken at window size 2 (2.098227585614946) (9999)
#  43%|████▎     | 3/7 [05:47<07:43, 115.94s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch/6256481/python/py_code/test_inflectionPoint.ipynb Cell 7 line 6
# ...

# %%
[5525]
ids = [5525, 6751, 6965, 7081, 7312, 7608, 8143]
for id in ids:
    print(id)
    dfReach      = df[df['combined_reach_id'] == id].copy()
    dfReachNodes = dfNode[dfNode['reach_id'].isin(dfReach['reach_id'].values)].copy()

    GroupedCRS = dfReach.groupby('localCRS', as_index = False).size()
    reachCRS   = GroupedCRS.loc[GroupedCRS['size'] == GroupedCRS['size'].max()
                                ,'localCRS'].iloc[0]

    dfReach      = dfReach.to_crs(reachCRS)
    dfReachNodes = dfReachNodes.to_crs(reachCRS)
    df.loc[dfReach.index, 'combined_reach_crs'] = reachCRS           

    combinedLine, _, _ = merge_centerlines(dfReach, df, reachCRS)
    
    line1 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.1,simplify_line = False)
    # line2 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.00001,simplify_line = True)
    # line3 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.000001,simplify_line = True)
    # line4 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.0000001,simplify_line = True)
    # line5 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.00000001,simplify_line = True)

    plt.plot(*combinedLine.xy)
    plt.plot(*line1.xy)
    plt.show()
    # print(len(line1.coords), len(line2.coords), len(line3.coords), len(line4.coords), len(line5.coords))
    print()
# Out:
# 5525
# 16342 16342
# 6751
# 8739 8739
# 6965
# 13204 13204
# 7081
# 14174 14174
# 7312
# 11832 11832
# 7608
# 17061 17061
# 8143
# 17619 17619

# %%
from scipy.spatial.distance import directed_hausdorff

# %%
len(combinedLine.coords)
A = combinedLine.segmentize(10000)
len(combinedLine.coords), len(A.coords)
# Out:
# (518, 518)

# %%
# check for multiple lines the distance between two lines, smoothed first or non smoothed first
line1 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.1,simplify_line = False)
line2 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.01,simplify_line = True)
line3 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 0.0000001,simplify_line = True)
line4 = SG_smoothing(combinedLine, smoothing_window, factorWidth, seg = 1,simp = 1,simplify_line = True)
len(line1.coords), len(line2.coords), len(line3.coords), len(line4.coords)
# Out:
# 16342
# 297
# Smoothing broken at window size 2 (9999)
# 300
# 288
# Smoothing broken at window size 2 (9999)
# (16342, 297, 300, 288)

# %%
# d, c1, c2    = directed_hausdorff(combinedLine.coords, combinedLineSmooth.coords)
# d1, c12, c11 = directed_hausdorff(line12.coords, line11.coords)
# d2, c22, c21 = directed_hausdorff(line22.coords, line21.coords)
# d3, c32, c31 = directed_hausdorff(line32.coords, line31.coords)
# d4, c42, c41 = directed_hausdorff(line42.coords, line41.coords)

plt.plot(*combinedLine.xy)
plt.plot(*line3.xy)
# plt.scatter(*line11.coords[c11], c = 'red', marker = 1)
# plt.scatter(*line12.coords[c12], c = 'red', marker = 1)

# plt.scatter(*line21.coords[c21], c = 'green')
# plt.scatter(*line22.coords[c22], c = 'green')

# plt.scatter(*line31.coords[c31], c = 'yellow')
# plt.scatter(*line32.coords[c32], c = 'yellow')

# plt.scatter(*line41.coords[c41], c = 'cyan')
# plt.scatter(*line42.coords[c42], c = 'cyan')

# plt.scatter(*combinedLine.coords[c1], c = 'blue')
# plt.scatter(*combinedLineSmooth.coords[c2], c = 'blue')
# print(d,d1,d2,d3,d4, shapely.hausdorff_distance(combinedLineSmooth, combinedLine))
print(shapely.hausdorff_distance(combinedLine, line1))
print(shapely.hausdorff_distance(combinedLine, line2))
print(shapely.hausdorff_distance(combinedLine, line3))
print(shapely.hausdorff_distance(combinedLine, line4))
# Out:
# 26.210520755344398
# 37.753582652819524
# 23.575421863208767
# 37.753582652819524

# %%
SG_smoothing(combinedLine, smoothing_window, factorWidth)
# Out:
# Window: 262.1258034243989, Distance: 464.4594608723375
# Window: 249.01951325317893, Distance: 434.2322424942208
# Window: 236.56853759051998, Distance: 401.7940545534795
# Window: 224.74011071099397, Distance: 371.52561161416384
# Window: 213.50310517544426, Distance: 343.9021916839882
# Window: 202.82794991667203, Distance: 323.3961128515772
# Window: 192.6865524208384, Distance: 310.15054906259513
# Window: 183.05222479979648, Distance: 296.67298550609524
# Window: 173.89961355980665, Distance: 280.0412758247516
# Window: 165.2046328818163, Distance: 266.11051965328255
# Window: 156.9444012377255, Distance: 250.06287881718933
# Window: 149.0971811758392, Distance: 237.33609348214435
# Window: 141.64232211704726, Distance: 222.69888174019894
# Window: 134.56020601119488, Distance: 209.75873863237865
# Window: 127.83219571063513, Distance: 196.71344790798102
# Window: 121.44058592510338, Distance: 185.47191886379133
# Window: 115.3685566288482, Distance: 174.2476227353359
# ...

# %%
from pipeline.line_functions import curvature

# %%
np.nanmean(curvature(bendLines[-1], False, False))
curvature(bendLines[-1], False, False)
# Out:
# array([-6.33975064e-12,  1.57493956e-12,  1.47108573e-04,  4.12452310e-04,
#         7.41003823e-04,  1.10448931e-03,  2.84746085e-03,  2.76776438e-03,
#         1.37401480e-03,  1.35940581e-03,  1.48213813e-03,  1.14197709e-03,
#         1.29551716e-03,  1.16618005e-03,  6.32376452e-04,  3.08415930e-04,
#         2.43140345e-04,  4.26196178e-04,  4.48716479e-04, -1.98276631e-12,
#        -7.47860825e-05, -3.92860650e-05, -7.04321316e-04, -1.98921263e-03,
#        -2.54855815e-03, -1.76419534e-03, -1.12678517e-03, -7.19349000e-04,
#        -6.87406245e-04, -4.07613209e-04, -9.87238015e-05, -1.16592007e-04,
#        -2.58407687e-04, -4.44561503e-04, -5.65887370e-04, -3.62841895e-04,
#        -1.52017107e-04,  1.19708817e-03,  4.81328039e-03,  1.45988575e-02,
#        -1.44413404e-01, -5.02007553e-01,  4.37044666e-10,  4.16260170e-10,
#         1.65668744e-09,  4.34258691e-09,  6.87890773e+17,  3.39427345e-10,
# ...

# %%
dfReach
# Out:
#                x          y     reach_id     reach_len  n_nodes         wse  \
# 4700 -155.923019  59.009319  81158000511   9546.898326       48  113.300003
# 4717 -156.148554  59.019250  81158000501  19997.501664      100   73.150002
#
#          wse_var  width    width_var         facc  ...  \
# 4700   97.896075   96.0  2100.674783  2522.268933  ...
# 4717  291.679016   87.0  1693.207612  4411.443216  ...
#
#       combined_reach_max_width  networkGroup   max_dist_out   up_reach_id  \
# 4700                289.023649             4  156169.076466  8.115800e+10
# 4717                289.023649             4  156169.076466  8.115800e+10
#
#       catchment_position  combined_reach_up  combined_reach_dn  \
# 4700            0.551769            13286.0            13288.0
# 4717            0.490637            13286.0            13288.0
#
#                                                geometry  combined_reach_crs  \
# ...

# %%
bendDO[10], bendDO[9]
# Out:
# (469812.0949770886, 469812.0949770886)

# %%
A = get_bend_dist_out(combinedLineSmooth, bendLines[9], dfReachNodes)
B = get_bend_dist_out(combinedLineSmooth, bendLines[10], dfReachNodes)
A, B
# Out:
# ?
# (469812.0949770886, 469812.0949770886)

# %%
end   = combinedLineSmooth.project(Point(bendLines[9].coords[-1]))
nodeDistance = dfReachNodes['linePos'] - end
ID = abs(nodeDistance).argmin()
dfReachNodes['dist_out'].iloc[ID] + nodeDistance.iloc[ID] * -1
# Out:
# 469798.692377867

# %%
end   = combinedLineSmooth.project(Point(bendLines[10].coords[-1]))
nodeDistance = dfReachNodes['linePos'] - end
ID = abs(nodeDistance).argmin()
dfReachNodes['dist_out'].iloc[ID] + nodeDistance.iloc[ID] * -1
# Out:
# 469496.3331917126

# %%
f,ax = plt.subplots()
dfReachNodes.iloc[-22:-16].plot(ax = ax)
plt.plot(*bendLines[9].xy)
plt.plot(*bendLines[10].xy)
plt.axis('equal')
plt.show()
dfReachNodes.iloc[-6::].linePos
# Out:
# 16311    1107.575370
# 16312     893.154742
# 16313     686.261099
# 16314     503.289196
# 16315     303.130831
# 16316     107.070915
# Name: linePos, dtype: float64

# %%
I = 0
plt.figure()
plt.scatter(*apexPList[I].xy, c = 'red')
plt.scatter(*apexPOList[I].xy, c = 'black')
plt.plot(*bendLines[I].xy, color = 'blue')

# plt.plot(*combinedLineSmooth.xy)
# plt.plot(*combinedLine.xy)
plt.axis('equal')
plt.show()

# %%
plt.plot(*bendLines[I].xy, color = 'blue')

# %%
# plt.plot(*combinedLineSmooth.xy)
for I in infT[-7::]:
    plt.scatter(*I, s = 10)
for I in inf[-5::]:
    plt.scatter(*I, s = 10, c = 'cyan')
plt.plot(*bendLines[-1].xy, 'black')
plt.plot(*bendLines[-2].xy, 'y')
plt.plot(*bendLines[-3].xy, 'g')
plt.plot(*bendLines[-4].xy, color = 'b')
# plt.plot(*bendLines[-5].xy, color = 'r')
plt.axis('equal')
# Out:
# (392920.29455845465, 393234.4547814293, 9758628.900038583, 9759731.100037975)

# %%
dfReach[['width', 'max_width', 'combined_reach_width']]
# Out:
#       width  max_width  combined_reach_width
# 4898   23.0       23.0                  23.0

# %%
trim_mean(dfReachNodes[~dfReachNodes['width'].isna()]['width'].values, 0.05), dfReachNodes['width'].std()
# Out:
# (36.97727272727273, 21.605790262620353)

# %%
from scipy.optimize import least_squares
from scipy import stats
def huber_mean_scipy(data, r=None):
    """
    Calculate Huber mean using scipy's least_squares with Huber loss.

    Parameters:
        data (array-like): Input 1D data.
        r (float, optional): The transition parameter. Defaults to 1.5 * std.

    Returns:
        float: Huber mean.
    """
    data = np.asarray(data)
    data = data[~np.isnan(data)]
    median = np.nanmedian(data)
    std = np.nanstd(data)
    if r is None:
        if std == 0:
            r = 1e-8  # or a very small number
        else:
            r = 1.5 * std


    # Objective function: residuals from the candidate mean
    def residual(mu):
        return data - mu

    result = least_squares(residual, x0=np.array([median]), loss='huber', f_scale=r)
    return result.x[0]



print(f'Trim: 5%: {stats.trim_mean(dfReachNodes['width'], 0.05)}')
print(f'Mean: {dfReachNodes['width'].mean()}')

print(f'Huber scipy: {huber_mean_scipy(dfReachNodes['width'])}')
print(f'Meadian: {np.median(dfReachNodes['width'])}')
# Out:
# Trim: 5%: 4164.645415907711
# Mean: 4237.3310552214325
# Huber scipy: 4156.772468586352
# Meadian: 4197.0

# %%
c = 'blue'
for i,I in enumerate(infT):
    if i == 148:
        c  = 'red'
        zorder = 100
    else:
        c = 'blue'
        zorder = 10
    plt.scatter(*I, c = c, zorder = zorder)

plt.axis('equal')
# Out:
# (162124.67625947288, 480629.3946688926, 9627629.544611476, 9735511.538828252)
