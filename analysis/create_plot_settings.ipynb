# %% [markdown]
# # Create plot settings confinement Paper

# %%
plot_settings = {
    'labelSize'         : 15,
    'tickSize'          : 12,
    'legendTitleSize'   : 12,
    'legendEntrySize'   : 12,
    'colorOut'          : '#d62728',
    'colorInn'          : '#1F60B4',
    'saveResolution'    : 1000
}
F = '/scratch/6256481/input_created/plot_settings_confinement.json'

import json
with open(F, 'w') as f:
    json.dump(plot_settings, f, indent=4)
